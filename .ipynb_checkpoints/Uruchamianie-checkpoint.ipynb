# %%
# importujemy tylko funkcje, których potrzebujemy
from wczytywanie import load_all_data, load_metadane

# %%
gios_archive_url = "https://powietrze.gios.gov.pl/pjp/archives/downloadFile/"
gios_url_ids = {2015: '236', 2018: '603', 2021: '486', 2024: '582'}
gios_pm25_file = {2015: '2015_PM25_1g.xlsx', 2018: '2018_PM25_1g.xlsx', 2021: '2021_PM25_1g.xlsx', 2024: '2024_PM25_1g.xlsx'}

# %%
all_data = load_all_data() #raw_all_data
# Out:
# Wczytywanie roku 2015...
# Wczytywanie roku 2018...
# Wczytywanie roku 2021...

# %%
all_data[2015]
# Out:
#                               0             1             2             3   \
# 0                     Kod stacji  DsJelGorOgin  DsWrocAlWisn  DsWrocWybCon
# 1                       Wskaźnik         PM2.5         PM2.5         PM2.5
# 2               Czas uśredniania            1g            1g            1g
# 3            2015-01-01 01:00:00       151.112            78            50
# 4            2015-01-01 02:00:00       262.566            42       33.8244
# ...                          ...           ...           ...           ...
# 8758  2015-12-31 20:00:43.770000       13.7734       29.2072       24.4965
# 8759  2015-12-31 21:00:43.775000       20.8195       36.8677       39.4025
# 8760  2015-12-31 22:00:43.780000       11.7978        61.041       52.4493
# 8761  2015-12-31 23:00:43.785000       16.6281       67.5414       59.3307
# 8762  2016-01-01 00:00:43.790000       16.1148       74.7532       91.8786
#
# ...

# %%
all_data[2018]
# Out:
#                        0             1             2             3   \
# 0                      Nr             1             2             3
# 1              Kod stacji  DsJelGorOgin  DsWrocAlWisn  DsWrocWybCon
# 2                Wskaźnik         PM2.5         PM2.5         PM2.5
# 3        Czas uśredniania            1g            1g            1g
# 4               Jednostka         ug/m3         ug/m3         ug/m3
# ...                   ...           ...           ...           ...
# 8761  2018-12-31 20:00:00       99,2267       43,6255       32,0664
# 8762  2018-12-31 21:00:00       99,0422       39,6576       41,8542
# 8763  2018-12-31 22:00:00       126,327       31,3481       30,4876
# 8764  2018-12-31 23:00:00         100,4       40,2615       30,8172
# 8765  2019-01-01 00:00:00       96,7489       40,3111       42,2584
#
#                 4             5             6             7             8   \
# ...

# %%
all_data[2021]
# Out:
#                        0             1             2            3   \
# 0                      Nr             1             2            3
# 1              Kod stacji  DsJelGorOgin  DsKlodzSzkol  DsMiliczMOB
# 2                Wskaźnik         PM2.5         PM2.5        PM2.5
# 3        Czas uśredniania            1g            1g           1g
# 4               Jednostka         ug/m3         ug/m3        ug/m3
# ...                   ...           ...           ...          ...
# 8761  2021-12-31 20:00:00       3.12917       7.45143       11.679
# 8762  2021-12-31 21:00:00       3.85694       8.97931      9.99029
# 8763  2021-12-31 22:00:00       4.06833       9.84656      8.56565
# 8764  2021-12-31 23:00:00       4.27861       13.6206      7.59395
# 8765  2022-01-01 00:00:00       6.79361       14.3734      8.38685
#
#                 4             5             6             7             8   \
# 0                4             5             6             7             8
# ...

# %%
all_data[2024]
# Out:
#                        0                1             2             3   \
# 0                      Nr                1             2             3
# 1              Kod stacji  DsChojnowMalMOB  DsJelGorOgin  DsKlodzSzkol
# 2                Wskaźnik            PM2.5         PM2.5         PM2.5
# 3        Czas uśredniania               1g            1g            1g
# 4               Jednostka            ug/m3         ug/m3         ug/m3
# ...                   ...              ...           ...           ...
# 8785  2024-12-31 20:00:00               53          48.3          34.3
# 8786  2024-12-31 21:00:00             33.7            67          33.3
# 8787  2024-12-31 22:00:00             57.7          72.7          32.4
# 8788  2024-12-31 23:00:00             75.5          79.9          30.7
# 8789  2025-01-01 00:00:00            144.7          67.9          26.4
#
#                    4             5             6             7             8   \
# ...

# %%
meta = load_metadane

# %%
from czyszczenie_danych import prepare_to_analize
cleared_all_data = prepare_to_analize(all_data, meta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from czyszczenie_danych import prepare_to_analize
# ----> 2 cleared_all_data = prepare_to_analize(all_data, meta)
#
# NameError: name 'all_data' is not defined

# %%
from analiza import combine_years
final_df = combine_years(cleared_all_data)
